# %% [markdown]
# # Draw on images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line
#
# - Start point
# - End point
# - Color
# - Thikness

# %%
img = np.zeros((500, 500, 3), np.uint8)
cv2.line(img,(0,0),(511,511),(0,0,255),5)
plt.imshow(img[:,:,::-1]);

# %%
def nothing(x):
    pass

cv2.namedWindow('Image')

cv2.createTrackbar('x0', 'Image', 0, 500, nothing)
cv2.createTrackbar('y0', 'Image', 0, 500, nothing)
cv2.createTrackbar('x1', 'Image', 0, 500, nothing)
cv2.createTrackbar('y1', 'Image', 0, 500, nothing)
cv2.createTrackbar('b', 'Image', 0, 255, nothing)
cv2.createTrackbar('g', 'Image', 0, 255, nothing)
cv2.createTrackbar('r', 'Image', 0, 255, nothing)
cv2.createTrackbar('th', 'Image', 0, 10, nothing)

while 1:
    img = np.zeros((500, 500, 3), np.uint8)
    x0 = cv2.getTrackbarPos('x0', 'Image')
    y0 = cv2.getTrackbarPos('y0', 'Image')
    x1 = cv2.getTrackbarPos('x1', 'Image')
    y1 = cv2.getTrackbarPos('y1', 'Image')
    b = cv2.getTrackbarPos('b', 'Image')
    g = cv2.getTrackbarPos('g', 'Image')
    r = cv2.getTrackbarPos('r', 'Image')
    th = cv2.getTrackbarPos('th', 'Image')

    cv2.line(img, (x0, y0), (x1, y1), (b,g,r), th+1)
    cv2.imshow('Image', img)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## Rectangle
#
# - Start point
# - End point
# - Color
# - Thikness
#   - -1 ?!

# %%
img = np.zeros((500, 500, 3), np.uint8)
cv2.rectangle(img, (10,10), (250,250), (0,0,255), 5)
plt.imshow(img[:,:,::-1]);

# %%
def nothing(x):
    pass

cv2.namedWindow('Image')

cv2.createTrackbar('x0', 'Image', 0, 500, nothing)
cv2.createTrackbar('y0', 'Image', 0, 500, nothing)
cv2.createTrackbar('x1', 'Image', 1, 500, nothing)
cv2.createTrackbar('y1', 'Image', 1, 500, nothing)
cv2.createTrackbar('th', 'Image', 1, 100, nothing)

while 1:
    img = np.zeros((500, 500, 3), np.uint8)
    x0 = cv2.getTrackbarPos('x0', 'Image')
    y0 = cv2.getTrackbarPos('y0', 'Image')
    x1 = cv2.getTrackbarPos('x1', 'Image')
    y1 = cv2.getTrackbarPos('y1', 'Image')
    th = cv2.getTrackbarPos('th', 'Image')
    typ = cv2.getTrackbarPos('type', 'Image')

    cv2.rectangle(
        img,
        (x0, y0), (x1, y1),
        (0, 0, 255), th-1
    )
    cv2.imshow('Image', img)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# # Circle
#
# - Center
# - Radius
# - Color
# - Thikness

# %%
img = np.zeros((500, 500, 3), np.uint8)
cv2.circle(img, (250,250), 100, (0,0,255), 10)
plt.imshow(img[:,:,::-1]);

# %%
def nothing(x):
    pass

cv2.namedWindow('Image')

cv2.createTrackbar('x', 'Image', 0, 500, nothing)
cv2.createTrackbar('y', 'Image', 0, 500, nothing)
cv2.createTrackbar('r', 'Image', 1, 500, nothing)
cv2.createTrackbar('th', 'Image', 1, 100, nothing)

while 1:
    img = np.zeros((500, 500, 3), np.uint8)
    x = cv2.getTrackbarPos('x', 'Image')
    y = cv2.getTrackbarPos('y', 'Image')
    r = cv2.getTrackbarPos('r', 'Image')
    th = cv2.getTrackbarPos('th', 'Image')

    cv2.circle(img, (x, y), r, (0, 0, 255), th-1)
    cv2.imshow('Image', img)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## Ellipse
#
# - Center
# - Major axis length
# - Minor axis length
# - Rotation angle
# - Start angle
# - End angle
#
# ![img](Files/ellipse.png)

# %%
img = np.zeros((500, 500, 3), np.uint8)
cv2.ellipse(img,(250,250),(100,50),0,0,305,(0,0,255),-1)
plt.imshow(img[:,:,::-1]);

# %%
def nothing(x):
    pass

cv2.namedWindow('Image')

cv2.createTrackbar('w', 'Image', 0, 250, nothing)
cv2.createTrackbar('h', 'Image', 0, 250, nothing)
cv2.createTrackbar('rot', 'Image', 0, 360, nothing)
cv2.createTrackbar('start', 'Image', 0, 360, nothing)
cv2.createTrackbar('end', 'Image', 0, 360, nothing)

while 1:
    img = np.zeros((500, 500, 3), np.uint8)
    w = cv2.getTrackbarPos('w', 'Image')
    h = cv2.getTrackbarPos('h', 'Image')
    rot = cv2.getTrackbarPos('rot', 'Image')
    start = cv2.getTrackbarPos('start', 'Image')
    end = cv2.getTrackbarPos('end', 'Image')

    cv2.ellipse(img, (250, 250), (w, h), rot, start, end, (0, 0, 255), -1)
    cv2.imshow('Image', img)
    k = cv2.waitKey(1)
    if k == ord('q'):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## Polygon
#
# - Array of points.
# - Close the shape.
# - Color.
# - Thikness.

# %%
img = np.zeros((500, 500, 3), np.uint8)
pts = np.array(
    [
        [10,20],[300,20],[150,100],[100,160],[20, 70]
    ]
    , np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img, [pts], True, (255,0,0), 0)
plt.imshow(img);

# %% [markdown]
# # Write on images
#
# - Text.
# - Start pixel.
# - Font.
# - Size.
# - Color.
# - Thikness.
# - Line type:
#   - cv2.FILLED
#   - cv2.Line_4
#   - cv2.Line_8
#   - cv2.Line_AA
#
# ## What is the diffrence ?

# %%
img = np.zeros((450, 600, 3), np.uint8)
plt.figure(figsize=(20, 15));
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 'Tekomoro', (2, 100), font, 4, (0, 0, 255), 6, cv2.FILLED)
cv2.putText(img, 'Tekomoro', (2, 200), font, 4, (0, 0, 255), 6, cv2.LINE_4)
cv2.putText(img, 'Tekomoro', (2, 300), font, 4, (0, 0, 255), 6, cv2.LINE_8)
cv2.putText(img, 'Tekomoro', (2, 400), font, 4, (0, 0, 255), 6, cv2.LINE_AA)
plt.imshow(img[:,:,::-1]);

# %% [markdown]
# # Mouse Events

# %% [markdown]
# ## Double Click

# %%
import numpy as np
import cv2 as cv

# mouse callback function
def draw_circle(event,x,y,flags,param):
    if event == cv.EVENT_LBUTTONDBLCLK:
        cv.circle(img,(x,y),50,(0,0, 255),-1)

# Create a black image, a window and bind the function to window
img = np.zeros((512,512,3), np.uint8)

cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle)

while(1):
    cv.imshow('image',img)
    if cv.waitKey(20) == ord('q'):
        break

cv.destroyAllWindows()

# %% [markdown]
# # More Mouse Events
#
# - Mouse Down.
# - Mouse Up.
# - Mouse Move.

# %%
import numpy as np
import cv2 as cv

drawing = False # true if mouse is pressed
mode = True # if True, draw rectangle. Press 'm' to toggle to curve
ix,iy = -1,-1

# mouse callback function
def draw_circle(event,x,y,flags,param):
    global ix,iy,drawing,mode
    if event == cv.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv.EVENT_MOUSEMOVE:
        if drawing == True:
            if mode == True:
                cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
            else:
                cv.circle(img,(x,y),5,(0,0,255),-1)
    elif event == cv.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
            cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
        else:
            cv.circle(img,(x,y),5,(0,0,255),-1)

img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle)

while(1):
    cv.imshow('image',img)
    
    k = cv.waitKey(1)
    if k == ord('m'):
        mode = not mode
    if k == ord('r'):
        img = np.zeros((512,512,3), np.uint8)
    if k == ord('q'):
        break

cv.destroyAllWindows()
